# %% [raw]
# To view NetCDF file attributes in a terminal, use:
# module load netcdf
# ncdump -h ‘filename’
#
# GitHub username
# calumknight
# GitHub token
# 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

# %% [markdown]
# Import packages and navigate to model data directory

# %%
import os
import emc2
import xarray as xr
import pandas as pd
import numpy as np
from datetime import datetime
from emc2.core import Instrument
from emc2.core.instrument import ureg
from emc2.core.instruments import HSRL
from emc2.core.instruments import WACR
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.colors import LogNorm

# Navigate to the ACCESS-AM2 data directory
os.chdir('/g/data/jk72/slf563/ACCESS/output/cc407/hourly')
# Check current project directory
print("Project directory:", os.getcwd())
# Out:
# Project directory: /g/data/jk72/slf563/ACCESS/output/cc407/hourly

# %% [markdown]
# # File saving

# %% [markdown]
# Load MARCUS coordinate data

# %%
# Load data and reformat as datetime64
marcus_coordinates_v1_3 = pd.read_csv('/g/data/jk72/ck4840/projects/emc2/data/marcus_coordinates/marcus_coordinates_v1_3.csv')
marcus_coordinates_v1_3['datetime_day'] = pd.to_datetime(marcus_coordinates_v1_3['datetime_day'])

# %% [markdown]
# Create the list of model output files to load, subset, and clean up

# %%
# Initialise the empty list
ACCESS_AM2_list = []
# Walk through the directory tree and search for 'met' in filenames
for root, dirs, files in os.walk(os.getcwd()):
    for filename in files:
        # Check if the filename contains 'met'
        if 'met' in filename:
            # If 'met' is present, create the full file path and append it to the list
            file_path = os.path.join(root, filename)
            ACCESS_AM2_list.append(file_path)

# Arrange the list by file date
# Define a function to extract the date from the file path
def extract_date(path):
    # Split the path by '/'
    path_split = path.split('.')
    # Get the part containing the date (e.g. '20170901')
    date_part = next(part for part in path_split if part.startswith('met20'))
    # Extract and return the date portion (e.g., '20170901')
    return date_part[3:11]

# Define a function to extract the numeric part of the filename
def extract_numeric_filename(filename):
    return int(filename.split('_')[-1].split('.')[2][3:11]) # Extract the numeric part and convert to integer

# Sort ACCESS_AM2_list based on the extracted date and numeric part of the filename
ACCESS_AM2_list = sorted(
    ACCESS_AM2_list,
    key = lambda path: (extract_date(path), extract_numeric_filename(os.path.basename(path)))
)

# Define the cutoff dates
cutoff_dates = [datetime(2017, 10, 29), datetime(2018, 2, 28)]

# Create a new list to store filtered files
ACCESS_AM2_list_filtered = []

# Iterate over each file in ACCESS_AM2_list
for file in ACCESS_AM2_list:
    # Extract the date string from the file path
    date_str = datetime.strptime(file.split('/')[-1].split('.')[2][-8:], '%Y%m%d')
    
    # Check if the date is within the specified bounds
    if cutoff_dates[0] <= date_str <= cutoff_dates[-1]:
        # If the date is within the bounds, add the file to the filtered list
        ACCESS_AM2_list_filtered.append(file)

# Display the sorted list
# ACCESS_AM2_list_filtered
print(len(ACCESS_AM2_list_filtered))
ACCESS_AM2_list_filtered[99]
# Out:
# 123
# '/g/data/jk72/slf563/ACCESS/output/cc407/hourly/cc407a.ph.met20180205.nc'

# %%
file = ACCESS_AM2_list_filtered[95]
date_str = file.split('/')[-1].split('.')[2][-8:]
date_str
# Out:
# '20180201'

# %% [markdown]
# Load, subset, clean, and resave ACCESS-AM2 model data

# %%
# Create the list of unique ACCESS-AM2 daily files between 2017-10-29 and 2018-02-28
ACCESS_AM2_list_unique = np.unique(ACCESS_AM2_list_filtered)
# TEST DAY 2018-02-05 (ACCESS_AM2_list_unique[99])
ACCESS_AM2_list_unique = [ACCESS_AM2_list_unique[95]]
print(ACCESS_AM2_list_unique)

# Loop through ACCESS_AM2_list_unique
for file in ACCESS_AM2_list_unique:
    ACCESS_AM2_output = xr.open_dataset(file)

    # Extract date from filename
    date_str = file.split('/')[-1].split('.')[2][-8:]

    # Drop unnecessary variables from the dataset
    # Drop the coordinates lat_v, time1, and z0_hybrid_height
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('lat_v')
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('time1')
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('z0_hybrid_height')
    # Drop fields deemed unnecessary for EMC2
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('va') # V component of wind
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('theta') # Potential temperature
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('hus') # Specific humidity
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field12') # Cloud ice mass mixing ratio
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('bldepth') # Boundary layer depth
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('sic') # Sea ice fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('sit') # Sea ice depth
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field150') # W component of wind
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field254') # Cloud liquid mass mixing ratio
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field265') # Area cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field266') # Bulk cloud fraction
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field267') # Liquid cloud fraction
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field268') # Frozen cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field272') # Rain number concentration, else mixing ratio if consistent with UM_reg
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field392') # Cloud liquid mixing ratio
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field393') # Cloud ice mixing ratio
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field394') # Rain mixing ratio
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field395') # Graupel mixing ratio
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field396') # Ice crystal (precip?) mixing ratio
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field408') # Pressure
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('ps') # Surface pressure
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('ts') # Sea surface temperature
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('ts_1') # Sea-ice surface temperature
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field509') # Sea ice albedo
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rss') # Net down surface SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rsdt') # Incoming TOA SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rsut') # Outgoing TOA SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rsutcs') # Clear sky outgoing TOA SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rsdscs') # Clear sky incoming surface SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rsuscs') # Clear sky outgoing surface SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rsds') # Total incoming surface SW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rls') # Net incoming surface LW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('clt') # Total cloud amount in LW radiation (cloud area fraction)
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rlut') # Outgoing TOA LW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rlutcs') # Clear sky outgoing TOA LW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rlds') # Incoming surface LW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rldscs') # Clear sky incoming surface LW flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2330') # COSP cloud weights
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2451') # COSP cloud area
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2452') # COSP liquid cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2453') # COSP ice cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2454') # COSP high-level cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2455') # COSP mid-level cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2456') # COSP low-level cloud fraction
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2457') # COSP tau
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2463') # COSP Reff liquid
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2464') # COSP Reff ice
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2465') # COSP cloud top pressure
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2466') # COSP liquid water path
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field2467') # COSP ice water path
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('vas') # Northward wind
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('hfss') # Surface upward sensible heat flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field3230') # 10 metre wind speed on C grid
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('hfls') # Surface upward latent heat flux
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('tas') # Temperature at 1.5 m
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('huss') # Specific humidity at 1.5 m
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field3245') # Relative humidity at 1.5 m
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('rlut_1') # Outgoing TOA LW flux after BL
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4113') # Graupel radar reflectivity
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4114') # Ice aggregate radar reflectivity
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4115') # Ice crystal radar reflectivity
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4116') # Rain radar reflectivity
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4117') # Liquid cloud radar reflectivity
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4203') # Large scale rainfall rate
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4204') # Large scale snowfall rate
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field4210') # Cloud liquid number concentration /m^3
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field5205') # Convective rainfall rate
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field5206') # Convective snowfall rate
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('prrn') # Total rainfall rate
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('prsn') # Total snowfall rate
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('pr') # Total precipitation rate
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field9203') # Low cloud amount
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field9204') # Medium cloud amount
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field9205') # High cloud amount
    # ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('ta') # Temperature
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('psl') # Air pressure at sea level
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('lwp') # Cloud liquid water content
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('clivi') # Cloud ice content
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field30453') # Height at tropopause level
    ACCESS_AM2_output = ACCESS_AM2_output.drop_vars('field30461') # Total column Q    

    # Extract the date from the 'time' coordinate in the model data and filter the MARCUS coordinate data to the model data date
    marcus_coordinates_current = marcus_coordinates_v1_3[marcus_coordinates_v1_3['datetime_day'].dt.date == pd.to_datetime(ACCESS_AM2_output['time'].values).date[0]]
    # Convert MARCUS coordinate data to XArray dataset and convert datetime_hour variable to a coordinate
    marcus_coordinates_current = xr.Dataset.from_dataframe(marcus_coordinates_current)
    marcus_coordinates_current = marcus_coordinates_current.set_coords(['datetime_hour'])

    # Subset the ACCESS-AM2 model data to the MARCUS Underway coordinates
    # Extract the time values from the ACCESS-AM2 output
    time_values = ACCESS_AM2_output['time'].values
    time_dataset = xr.Dataset({'time': time_values})
    # Initialize lists to store latitudes and longitudes
    lat_values = []
    lon_values = []
    # Initalise list to store the individual datasets from each iteration
    list_of_datasets = []
    # Loop over each time step in the ship dataset
    for i in range(len(marcus_coordinates_current['datetime_hour'])):
        # Get the lat, lon, and time values for each step
        lat = marcus_coordinates_current['latitude'].isel(index=i)
        lon = marcus_coordinates_current['longitude'].isel(index=i)
        time = marcus_coordinates_current['datetime_hour'].isel(index=i)
        # Extract the current lat and lon values
        lat_values.append(lat)
        lon_values.append(lon)
        # Interpolating the entire dataset at the ship's position
        ACCESS_AM2_output_interpolated = ACCESS_AM2_output.interp(
            lat=lat.item(),
            lon=lon.item(),
            time=time_values[i],
            method='nearest')
        # Drop the current latitude and longitude coordinates
        ACCESS_AM2_output_interpolated = ACCESS_AM2_output_interpolated.drop_vars('lat')
        ACCESS_AM2_output_interpolated = ACCESS_AM2_output_interpolated.drop_vars('lon')
        # Append each interpolated dataset to the list
        list_of_datasets.append(ACCESS_AM2_output_interpolated)
    # Concatenate all datasets along a new dimension 'index'
    ACCESS_AM2_output_subset = xr.combine_nested(list_of_datasets, concat_dim='time')
    # Merge the 'time' dataset with the combined dataset
    ACCESS_AM2_output_subset = xr.merge([time_dataset, ACCESS_AM2_output_subset])
    # Add latitudes and longitudes as variables
    lat_values = xr.DataArray(data=lat_values, dims='dim_name')
    lon_values = xr.DataArray(data=lon_values, dims='dim_name')
    ACCESS_AM2_output_subset['lat'] = ('time', lat_values.data)
    ACCESS_AM2_output_subset['lon'] = ('time', lon_values.data)

    # Add a utility zero array to the dataset
    # Create a variable filled with zeros
    zeros_data = xr.DataArray(
        data = np.zeros((len(ACCESS_AM2_output_subset['time']), len(ACCESS_AM2_output_subset['z1_hybrid_height']))),
        dims = ('time', 'z1_hybrid_height'),
        coords = {'time': ACCESS_AM2_output_subset['time'], 'z1_hybrid_height': ACCESS_AM2_output_subset['z1_hybrid_height']})
    # Add the zeros variable to the dataset
    ACCESS_AM2_output_subset['zeros_var'] = zeros_data

    # Add a 2-dimensional z_values variable to the dataset
    # Extract the z1_hybrid_height coordinate from the dataset
    z1_values = ACCESS_AM2_output_subset['z1_hybrid_height'].values
    # Create 2D array z_values from 1D array z1_values
    z_values = z1_values[:, np.newaxis] * np.ones(len(ACCESS_AM2_output_subset['time']))
    # Reinsert z variable into the dataset
    ACCESS_AM2_output_subset['z'] = (('z1_hybrid_height', 'time'), z_values)
    ACCESS_AM2_output_subset['z'].attrs['units'] = 'meters'
    ACCESS_AM2_output_subset['z'] = ACCESS_AM2_output_subset['z'].transpose('time', 'z1_hybrid_height')

    # Estimate particle effective radius for each species and add it to the data subset
    # Cloud liquid
    # Extract/calculate required variables and set constants
    qcl = ACCESS_AM2_output_subset.field254 # kg/kg (unitless)
    rhoa = ACCESS_AM2_output_subset.field408/(ACCESS_AM2_output_subset.ta*287.058) # kg/m^3
    ncl = ACCESS_AM2_output_subset.field4210 # particles/m^3
    ncl_mass = ncl/rhoa # particles/kg
    # Parameterisation
    re_cl = ((((qcl/ncl_mass)/1000)*3)/(4*np.pi))**(1./3)
    #
    # Cloud ice
    # Extract/calculate required variables and set constants
    qci = ACCESS_AM2_output_subset.field12 # kg/kg
    rhoa = ACCESS_AM2_output_subset.field408/(ACCESS_AM2_output_subset.ta*287.058) # kg/m^3
    ta = ACCESS_AM2_output_subset.ta
    # Parameterisation
    Zqci = qci * rhoa * 1000.
    ZRefDe = 0.64952
    Z_TEMPC = ta - 83.15
    Z_TCELS = ta - 273
    Z_FSR = 1.2351 + 0.0105 * Z_TCELS
    ZAqci = 45.8966 * (Zqci ** 0.2214)
    ZBqci = 0.7957 * (Zqci ** 0.2535)
    Z_DESR = Z_FSR * (ZAqci + ZBqci * Z_TEMPC)
    # Z_DESR = (30. > Z_TEMPC < 155.) - reference range - values should be within these micron bounds
    re_ci = ZRefDe * Z_DESR * 1e-6
    #
    # Precipitating liquid
    # Note - there is no data for precipitating liquid particle number density, so currently a zeros array is used
    # NB: FIELD 272 IS RAIN AFTER TIMESTEP AND MAY BE RAIN NUMBER CONCENTRATION
    # Extract/calculate required variables and set constants
    qpl = ACCESS_AM2_output_subset.field394 # kg/kg (unitless)
    rhoa = ACCESS_AM2_output_subset.field408/(ACCESS_AM2_output_subset.ta*287.058) # kg/m^3
    npl = ACCESS_AM2_output_subset.zeros_var # particles/m^3
    npl_mass = npl/rhoa # particles/kg
    # Parameterisation
    re_pl = ((((qpl/npl_mass)/1000)*3)/(4*np.pi))**(1./3)
    #
    # Precipitating ice
    # Extract/calculate required variables and set constants
    qpi = ACCESS_AM2_output_subset.field396 # kg/kg
    rhoa = ACCESS_AM2_output_subset.field408/(ACCESS_AM2_output_subset.ta*287.058) # kg/m^3
    ta = ACCESS_AM2_output_subset.ta
    # Parameterisation
    Zqpi = qpi * rhoa * 1000.
    ZRefDe = 0.64952
    Z_TEMPC = ta - 83.15
    Z_TCELS = ta - 273
    Z_FSR = 1.2351 + 0.0105 * Z_TCELS
    ZAqpi = 45.8966 * (Zqpi ** 0.2214)
    ZBqpi = 0.7957 * (Zqpi ** 0.2535)
    Z_DESR = Z_FSR * (ZAqpi + ZBqpi * Z_TEMPC)
    # Z_DESR = (30. > Z_TEMPC < 155.) - reference range - values should be within these micron bounds
    re_pi = ZRefDe * Z_DESR * 1e-6
    # Add effective radius to the dataset
    ACCESS_AM2_output_subset['re_cl'] = xr.DataArray(data = re_cl,dims = ('time','z1_hybrid_height'))
    ACCESS_AM2_output_subset['re_ci'] = xr.DataArray(data = re_ci,dims = ('time','z1_hybrid_height'))
    ACCESS_AM2_output_subset['re_pl'] = xr.DataArray(data = re_pl,dims = ('time','z1_hybrid_height'))
    ACCESS_AM2_output_subset['re_pi'] = xr.DataArray(data = re_pi,dims = ('time','z1_hybrid_height'))
    # Replace effective radius nans with zeros
    ACCESS_AM2_output_subset['re_cl'] = ACCESS_AM2_output_subset['re_cl'].fillna(0)
    ACCESS_AM2_output_subset['re_ci'] = ACCESS_AM2_output_subset['re_ci'].fillna(0)
    ACCESS_AM2_output_subset['re_pl'] = ACCESS_AM2_output_subset['re_pl'].fillna(0)
    ACCESS_AM2_output_subset['re_pi'] = ACCESS_AM2_output_subset['re_pi'].fillna(0)
    # Replace effective radius inf with zeros
    ACCESS_AM2_output_subset['re_cl'] = xr.where(np.isinf(ACCESS_AM2_output_subset['re_cl']), 0, ACCESS_AM2_output_subset['re_cl'])
    ACCESS_AM2_output_subset['re_ci'] = xr.where(np.isinf(ACCESS_AM2_output_subset['re_ci']), 0, ACCESS_AM2_output_subset['re_ci'])
    ACCESS_AM2_output_subset['re_pl'] = xr.where(np.isinf(ACCESS_AM2_output_subset['re_pl']), 0, ACCESS_AM2_output_subset['re_pl'])
    ACCESS_AM2_output_subset['re_pi'] = xr.where(np.isinf(ACCESS_AM2_output_subset['re_pi']), 0, ACCESS_AM2_output_subset['re_pi'])

    # EXPERIMENTAL: CALCULATE NCF FROM RE_CI
    # ACCESS_AM2_output_subset.re_ci = ((((ACCESS_AM2_output_subset.field12/custom_ncf_field)/500)*3)/(4*np.pi))**(1./3)
    # (ACCESS_AM2_output_subset.re_ci**3) = (((ACCESS_AM2_output_subset.field12/custom_ncf_field)/500)*3)/(4*np.pi)
    # (ACCESS_AM2_output_subset.re_ci**3) * (4*np.pi) = ((ACCESS_AM2_output_subset.field12/custom_ncf_field)/500)*3
    # (ACCESS_AM2_output_subset.re_ci**3) * (4*np.pi)/3 = (ACCESS_AM2_output_subset.field12/custom_ncf_field)/500
    # 500 * (ACCESS_AM2_output_subset.re_ci**3) * (4*np.pi)/3 = ACCESS_AM2_output_subset.field12/custom_ncf_field
    # custom_ncf_field * 500 * (ACCESS_AM2_output_subset.re_ci**3) * (4*np.pi)/3 = ACCESS_AM2_output_subset.field12
    custom_ncf_field = 3 * ACCESS_AM2_output_subset.field12/(500 * (ACCESS_AM2_output_subset.re_ci**3) * (4*np.pi))
    # Add custom_ncf_field to the dataset
    ACCESS_AM2_output_subset['custom_ncf_field'] = xr.DataArray(data = custom_ncf_field,dims = ('time','z1_hybrid_height'))
    ACCESS_AM2_output_subset['custom_ncf_field'] = ACCESS_AM2_output_subset['custom_ncf_field'].fillna(0)
    ACCESS_AM2_output_subset['custom_ncf_field'] = xr.where(np.isinf(ACCESS_AM2_output_subset['custom_ncf_field']), 0, ACCESS_AM2_output_subset['custom_ncf_field'])

    # Add units to variables in the data subset
    # Pressure
    ACCESS_AM2_output_subset['field408'] = ACCESS_AM2_output_subset['field408'].assign_attrs(units=ureg.pascal)
    ACCESS_AM2_output_subset['field408'].attrs['units'] = str(ACCESS_AM2_output_subset['field408'].attrs['units'])
    # Temperature
    ACCESS_AM2_output_subset['ta'] = ACCESS_AM2_output_subset['ta'].assign_attrs(units=ureg.kelvin)
    ACCESS_AM2_output_subset['ta'].attrs['units'] = str(ACCESS_AM2_output_subset['ta'].attrs['units'])
    # Effective radius of particles
    ACCESS_AM2_output_subset['re_cl'] = ACCESS_AM2_output_subset['re_cl'].assign_attrs(units=ureg.meter)
    ACCESS_AM2_output_subset['re_cl'].attrs['units'] = str(ACCESS_AM2_output_subset['re_cl'].attrs['units'])
    ACCESS_AM2_output_subset['re_ci'] = ACCESS_AM2_output_subset['re_ci'].assign_attrs(units=ureg.meter)
    ACCESS_AM2_output_subset['re_ci'].attrs['units'] = str(ACCESS_AM2_output_subset['re_ci'].attrs['units'])
    ACCESS_AM2_output_subset['re_pl'] = ACCESS_AM2_output_subset['re_pl'].assign_attrs(units=ureg.meter)
    ACCESS_AM2_output_subset['re_pl'].attrs['units'] = str(ACCESS_AM2_output_subset['re_pl'].attrs['units'])
    ACCESS_AM2_output_subset['re_pi'] = ACCESS_AM2_output_subset['re_pi'].assign_attrs(units=ureg.meter)
    ACCESS_AM2_output_subset['re_pi'].attrs['units'] = str(ACCESS_AM2_output_subset['re_pi'].attrs['units'])
    # Water vapor mixing ratio
    ACCESS_AM2_output_subset['hus'] = ACCESS_AM2_output_subset['hus'].assign_attrs(units=ureg.meter**3/ureg.meter**3)
    ACCESS_AM2_output_subset['hus'].attrs['units'] = str(ACCESS_AM2_output_subset['hus'].attrs['units'])
    # Cloud droplet number concentration
    ACCESS_AM2_output_subset['field4210'] = ACCESS_AM2_output_subset['field4210'].assign_attrs(units=ureg.meter**(-3))
    ACCESS_AM2_output_subset['field4210'].attrs['units'] = str(ACCESS_AM2_output_subset['field4210'].attrs['units'])
    ACCESS_AM2_output_subset['custom_ncf_field'] = ACCESS_AM2_output_subset['custom_ncf_field'].assign_attrs(units=ureg.meter**(-3))
    ACCESS_AM2_output_subset['custom_ncf_field'].attrs['units'] = str(ACCESS_AM2_output_subset['custom_ncf_field'].attrs['units'])
    # Height field
    ACCESS_AM2_output_subset['z1_hybrid_height'] = ACCESS_AM2_output_subset['z1_hybrid_height'].assign_attrs(units=ureg.meter)
    ACCESS_AM2_output_subset['z1_hybrid_height'].attrs['units'] = str(ACCESS_AM2_output_subset['z1_hybrid_height'].attrs['units'])
    # Mass mixing ratios
    ACCESS_AM2_output_subset['field254'] = ACCESS_AM2_output_subset['field254'].assign_attrs(units=ureg.kg/ureg.kg)
    ACCESS_AM2_output_subset['field254'].attrs['units'] = str(ACCESS_AM2_output_subset['field254'].attrs['units'])
    ACCESS_AM2_output_subset['field12'] = ACCESS_AM2_output_subset['field12'].assign_attrs(units=ureg.kg/ureg.kg)
    ACCESS_AM2_output_subset['field12'].attrs['units'] = str(ACCESS_AM2_output_subset['field12'].attrs['units'])
    ACCESS_AM2_output_subset['field394'] = ACCESS_AM2_output_subset['field394'].assign_attrs(units=ureg.kg/ureg.kg)
    ACCESS_AM2_output_subset['field394'].attrs['units'] = str(ACCESS_AM2_output_subset['field394'].attrs['units'])
    ACCESS_AM2_output_subset['field396'] = ACCESS_AM2_output_subset['field396'].assign_attrs(units=ureg.kg/ureg.kg)
    ACCESS_AM2_output_subset['field396'].attrs['units'] = str(ACCESS_AM2_output_subset['field396'].attrs['units'])

    # Rename coordinates
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename({'z1_hybrid_height': 'height_coordinate'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename({'time': 'time_hour'})
    # Rename variables
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field267': 'liquid_fraction'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field268': 'ice_fraction'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field254': 'qcl'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field12': 'qci'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field394': 'qpl'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field396': 'qpi'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field4210': 'ncl'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'custom_ncf_field': 'nci'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'field408': 'pressure'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'ta': 'temperature'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'hus': 'q'})
    ACCESS_AM2_output_subset = ACCESS_AM2_output_subset.rename_vars({'z': 'height_values'})
    
    # Save the data
    file_path_output = f'/g/data/jk72/ck4840/projects/emc2/data/access_am2/access_am2_marcus_{date_str}.nc'
    # ACCESS_AM2_output_subset.to_netcdf(file_path_output)

print('Finished processing and saving files')
# Out:
# ['/g/data/jk72/slf563/ACCESS/output/cc407/hourly/cc407a.ph.met20180201.nc']
# Finished processing and saving files

# %%
ACCESS_AM2_output_subset
# Out:
# <xarray.Dataset>
# Dimensions:            (time_hour: 24, height_coordinate: 85)
# Coordinates:
#   * time_hour          (time_hour) datetime64[ns] 2018-02-01T01:00:00 ... 201...
#   * height_coordinate  (height_coordinate) float64 20.0 53.33 ... 8.5e+04
# Data variables: (12/19)
#     q                  (time_hour, height_coordinate) float32 0.002947 ... 2....
#     qci                (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     qcl                (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     liquid_fraction    (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     ice_fraction       (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     qpl                (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     ...                 ...
#     height_values      (time_hour, height_coordinate) float64 20.0 ... 8.5e+04
#     re_cl              (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     re_ci              (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     re_pl              (time_hour, height_coordinate) float64 0.0 0.0 ... 0.0
#     re_pi              (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0
#     nci                (time_hour, height_coordinate) float32 0.0 0.0 ... 0.0

# %%
# custom_ncf_field = ((re_ci**3) * 500 * np.pi * ACCESS_AM2_output_subset.field12)/3
print(np.max(ACCESS_AM2_output_subset.re_cl.values))
print(np.max(ACCESS_AM2_output_subset.re_ci.values))
print(np.max(ACCESS_AM2_output_subset.field254.values))
print(np.max(ACCESS_AM2_output_subset.field12.values))
print(np.max(ACCESS_AM2_output_subset.field4210.values))
print(np.max(ACCESS_AM2_output_subset.custom_ncf_field.values))
# Out:
# 9.140743e-06
# 0.00011513124
# 0.0002290049
# 0.00026321362
# 52428800.0
# 980386.2

# %%
print('Max values for ACCESS_AM2_output_subset fields')
print('\n')
print('Cloud liquid number concentration field')
print(np.max(ACCESS_AM2_output_subset.field4210.values))
print('Cloud ice number concentration field')
print(np.max(ACCESS_AM2_output_subset.custom_ncf_field.values))
print('\n')
print('Cloud liquid mass mixing ratio field')
print(np.max(ACCESS_AM2_output_subset.field254.values))
# print(np.max(ACCESS_AM2_output_subset.field392.values))
print('Cloud ice mass mixing ratio field')
print(np.max(ACCESS_AM2_output_subset.field12.values))
# print(np.max(ACCESS_AM2_output_subset.field393.values))
print('Precip. liquid mass mixing ratio field')
# print(np.max(ACCESS_AM2_output_subset.field272.values))
print(np.max(ACCESS_AM2_output_subset.field394.values))
print('Precip. ice mass mixing ratio field')
print(np.max(ACCESS_AM2_output_subset.field396.values))
print('\n')
print('Cloud liquid and ice fraction fields')
print(np.max(ACCESS_AM2_output_subset.field267.values))
print(np.max(ACCESS_AM2_output_subset.field268.values))
print('\n')
print('Pressure, temperature, and specific humidity fields')
print(np.max(ACCESS_AM2_output_subset.field408.values))
print(np.max(ACCESS_AM2_output_subset.ta.values))
print(np.max(ACCESS_AM2_output_subset.hus.values))
print('\n')
print('Particle effective radius fields')
print(np.max(ACCESS_AM2_output_subset.re_cl.values))
print(np.max(ACCESS_AM2_output_subset.re_ci.values))
print(np.max(ACCESS_AM2_output_subset.re_pl.values))
print(np.max(ACCESS_AM2_output_subset.re_pi.values))
print('\n')
# Out:
# Max values for ACCESS_AM2_output_subset fields
#
#
# Cloud liquid number concentration field
# 52428800.0
# Cloud ice number concentration field
# 980386.2
#
#
# Cloud liquid mass mixing ratio field
# 0.0002290049
# Cloud ice mass mixing ratio field
# 0.00026321362
# Precip. liquid mass mixing ratio field
# 5.9604645e-08
# Precip. ice mass mixing ratio field
# 0.0
#
#
# Cloud liquid and ice fraction fields
# 0.6594238
# 1.0
#
#
# Pressure, temperature, and specific humidity fields
# 98117.6
# 277.19684
# 0.0028395052
#
#
# Particle effective radius fields
# 9.140743e-06
# 0.00011513124
# 0.0
# 0.0

# %%
# To save plots, add this line after each plt.gcf() line
# daily_UM_reg_var.savefig(f'{plot_path}/UM_reg_var_{current_date}', dpi = 200)

# Create a meshgrid for time and height to be used for all plots produced from the current file
time_mesh, height_mesh = np.meshgrid(ACCESS_AM2_output_subset['time'], ACCESS_AM2_output_subset['z1_hybrid_height'])

# NCL
# Extract the desired variable
var = ACCESS_AM2_output_subset['field4210']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Cloud liquid number concentration (/m^3)')
plt.title('NCL vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# NCF
# Extract the desired variable
var = ACCESS_AM2_output_subset['custom_ncf_field']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Cloud ice number concentration (/m^3)')
plt.title('NCF vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# QCL
# Extract the desired variable
var = ACCESS_AM2_output_subset['field254']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Cloud liquid mass mixing ratio (unitless)')
plt.title('QCL vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# # QCL2
# # Extract the desired variable
# var = ACCESS_AM2_output_subset['field392']
# # Create the plot with a grey background
# plt.figure(figsize = (12, 6))
# plt.gca().set_facecolor('lightgrey')
# # Create and organise a pcolormesh plot
# pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
# plt.xlabel('Time')
# plt.ylabel('Height (m)')
# plt.colorbar(pcm, label = 'Cloud liquid mass mixing ratio 2 (unitless)')
# plt.title('QCL2 vs. time and height')
# plt.ylim(0, 4000)
# plt.xticks(rotation = 45)
# plt.tight_layout()
# daily_UM_reg_var = plt.gcf()
# QCF
# Extract the desired variable
var = ACCESS_AM2_output_subset['field12']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Cloud ice mass mixing ratio (unitless)')
plt.title('QCF vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# # QCF2
# # Extract the desired variable
# var = ACCESS_AM2_output_subset['field393']
# # Create the plot with a grey background
# plt.figure(figsize = (12, 6))
# plt.gca().set_facecolor('lightgrey')
# # Create and organise a pcolormesh plot
# pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
# plt.xlabel('Time')
# plt.ylabel('Height (m)')
# plt.colorbar(pcm, label = 'Cloud ice mass mixing ratio 2 (unitless)')
# plt.title('QCF2 vs. time and height')
# plt.ylim(0, 4000)
# plt.xticks(rotation = 45)
# plt.tight_layout()
# daily_UM_reg_var = plt.gcf()
# QPL
# Extract the desired variable
var = ACCESS_AM2_output_subset['field394']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Precip. liquid mass mixing ratio (QPL; unitless)')
plt.title('QPL vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# # QPL2
# # Extract the desired variable
# var = ACCESS_AM2_output_subset['field272']
# # Create the plot with a grey background
# plt.figure(figsize = (12, 6))
# plt.gca().set_facecolor('lightgrey')
# # Create and organise a pcolormesh plot
# pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
# plt.xlabel('Time')
# plt.ylabel('Height (m)')
# plt.colorbar(pcm, label = 'Precip. liquid mass mixing ratio 2 (unitless)')
# plt.title('QPL2 vs. time and height')
# plt.ylim(0, 4000)
# plt.xticks(rotation = 45)
# plt.tight_layout()
# daily_UM_reg_var = plt.gcf()
# QPF
# Extract the desired variable
var = ACCESS_AM2_output_subset['field396']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Precip. ice mass mixing ratio (unitless)')
plt.title('QPF vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# Cloud liquid water fraction
# Extract the desired variable
var = ACCESS_AM2_output_subset['field267']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Liquid cloud fraction (unitless)')
plt.title('Liquid cloud fraction vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# Cloud ice water fraction
# Extract the desired variable
var = ACCESS_AM2_output_subset['field268']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Ice cloud fraction (unitless)')
plt.title('Ice cloud fraction vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# Pressure
# Extract the desired variable
var = ACCESS_AM2_output_subset['field408']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Pressure (Pa)')
plt.title('Pressure vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# Temperature
# Extract the desired variable
var = ACCESS_AM2_output_subset['ta']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Temperature (K)')
plt.title('Temperature vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# Specific humidity
# Extract the desired variable
var = ACCESS_AM2_output_subset['hus']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Specific humidity (unitless)')
plt.title('HUS vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# Particle effective radius fields
# Cloud liquid effective radius
# Extract the desired variable
var = ACCESS_AM2_output_subset['re_cl']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Cloud liquid effective radius (m)')
plt.title('ReCL vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# Cloud ice effective radius
# Extract the desired variable
var = ACCESS_AM2_output_subset['re_ci']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Cloud ice effective radius (m)')
plt.title('ReCI vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# Preip. liquid effective radius
# Extract the desired variable
var = ACCESS_AM2_output_subset['re_pl']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Precip. liquid effective radius (m)')
plt.title('RePL vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()
# Precip. ice effective radius
# Extract the desired variable
var = ACCESS_AM2_output_subset['re_pi']
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, var.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Precip. ice effective radius (m)')
plt.title('RePI vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
daily_UM_reg_var = plt.gcf()

# %% [markdown]
# Create the ACCESS-AM2 model class

# %%
class ACCESS_AM2(emc2.core.Model):
    def __init__(self, file_path):
       """
       This loads an ACCESS-AM2 simulation with all of the necessary parameters for EMC^2 to run.
       
       Parameters
       ----------
       file_path: str
           Path to an ACCESS-AM2 simulation.
       time_range: tuple, list, or array, typically in datetime64 format
           Two-element array with starting and ending of time range.
       load_processed: bool
           If True, treating the 'file_path' variable as an EMC2-processed dataset; thus skipping dimension stacking as part of pre-processing.
       """
       
       super().__init__()
       
       # Bulk density
       self.Rho_hyd = {'cl': 1000. * ureg.kg / (ureg.m**3),
                       'ci': 500.  * ureg.kg / (ureg.m**3),
                       'pl': 1000. * ureg.kg / (ureg.m**3),
                       'pi': 250.  * ureg.kg / (ureg.m**3)}
       self.fluffy = {'ci': 0.5 * ureg.dimensionless,
                      'pi': 0.5 * ureg.dimensionless}
       # Lidar ratio
       self.lidar_ratio = {'cl': 18.  * ureg.dimensionless,
                           'ci': 24.  * ureg.dimensionless,
                           'pl': 5.5  * ureg.dimensionless,
                           'pi': 24.0 * ureg.dimensionless}
       # Lidar LDR per hydrometeor mass content
       self.LDR_per_hyd = {'cl': 0.03 * 1 / (ureg.kg / (ureg.m**3)),
                           'ci': 0.35 * 1 / (ureg.kg / (ureg.m**3)),
                           'pl': 0.1  * 1 / (ureg.kg / (ureg.m**3)),
                           'pi': 0.40 * 1 / (ureg.kg / (ureg.m**3))}
       # a, b in V = aD^b
       self.vel_param_a = {'cl': 3e7,
                           'ci': 700.,
                           'pl': 841.997,
                           'pi': 11.72}
       self.vel_param_b = {'cl': 2.   * ureg.dimensionless,
                           'ci': 1.   * ureg.dimensionless,
                           'pl': 0.8  * ureg.dimensionless,
                           'pi': 0.41 * ureg.dimensionless}
       super()._add_vel_units()
       # Names of mixing ratios of species
       # What is the difference between field254 and field392? Also, what is the difference between field12 and field393?
       self.q_names = {'cl': 'field254', 'ci': 'field12', 'pl': 'field394', 'pi': 'field396'}
       # Number concentration of each species
       self.N_field = {'cl': 'field4210', 'ci': 'custom_ncf_field', 'pl': 'zeros_var', 'pi': 'zeros_var'} # Need number concentrations of each species
       # Convective fraction
       self.conv_frac_names = {'cl': 'zeros_var', 'ci': 'zeros_var', 'pl': 'zeros_var', 'pi': 'zeros_var'}
       self.conv_frac_names_for_rad = {'cl': 'zeros_var', 'ci': 'zeros_var', 'pl': 'zeros_var', 'pi': 'zeros_var'}
       # Stratiform fraction
       self.strat_frac_names = {'cl': 'field267', 'ci': 'field268', 'pl': 'zeros_var', 'pi': 'zeros_var'}
       self.strat_frac_names_for_rad = {'cl': 'field267', 'ci': 'field268', 'pl': 'zeros_var', 'pi': 'zeros_var'}
       # Effective radius
       self.re_fields = {'cl': 're_cl', 'ci': 're_ci', 'pl': 're_pl', 'pi': 're_pi'}
       self.strat_re_fields = {'cl': 're_cl', 'ci': 're_ci', 'pl': 're_pl', 'pi': 're_pi'}
       self.conv_re_fields = {'cl': 'zeros_var', 'ci': 'zeros_var', 'pl': 'zeros_var', 'pi': 'zeros_var'}
       # Convective mixing ratio
       self.q_names_convective = {'cl': 'zeros_var', 'ci': 'zeros_var', 'pl': 'zeros_var', 'pi': 'zeros_var'}
       # Stratiform mixing ratio
       self.q_names_stratiform = {'cl': 'field254', 'ci': 'field12', 'pl': 'field394', 'pi': 'field396'}
       # Water vapor mixing ratio
       self.q_field = "hus"
       # Pressure
       self.p_field = "field408"
       # Height
       self.z_field = "z"
       # Temperature
       self.T_field = "ta"
       # Name of height dimension
       self.height_dim = "z1_hybrid_height"
       # Name of time dimension
       self.time_dim = "time"
       self.hyd_types = ["cl", "ci", "pl", "pi"]
       self.process_conv = False
       self.model_name = "ACCESS_AM2"
       # self.ds = xr.open_dataset(file_path)
       self.ds = ACCESS_AM2_output_subset

# %% [markdown]
# Create the MPL instrument class instance

# %%
MPL = HSRL()
# print(dir(MPL))

# %% [markdown]
# Create the MWACR instrument class instance

# %%
MWACR = WACR(site = 'micre')
# print(dir(MWACR))

# %% [markdown]
# Create the ACCESS-AM2 model class instance

# %%
ACCESS_AM2_instance = ACCESS_AM2(ACCESS_AM2_output_subset)
# print(dir(ACCESS_AM2_instance))

# %% [markdown]
# Create simulated data from ACCESS_AM2_instance and MPL

# %%
# Create simulated lidar data
marcus_MPL_ACCESS_AM2_model = emc2.simulator.main.make_simulated_data(ACCESS_AM2_instance, MPL, N_columns = 1, do_classify = True, convert_zeros_to_nan = True, use_rad_logic = False)
# dir(marcus_MPL_ACCESS_AM2_model)
# Out:
# ## Creating subcolumns...
# No convective processing for ACCESS_AM2
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns frac fields to 1 for startiform cl and ci based on q > 0. kg/kg
# Done! total processing time = 0.01s
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns frac fields to 1 for strat precip based on q > 0. kg/kg
# Done! total processing time = 0.01s
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for cl equal to grid-cell mean
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for ci equal to grid-cell mean
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for pl equal to grid-cell mean
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for pi equal to grid-cell mean
# Generating lidar moments...
# Generating stratiform lidar variables using microphysics logic (slowest processing)
# Generating stratiform lidar variables for hydrometeor class cl
# Doing parallel lidar calculations for cl
# Stratiform moment for class cl progress: 0/24
# Generating stratiform lidar variables for hydrometeor class ci
# Doing parallel lidar calculations for ci
# Stratiform moment for class ci progress: 0/24
# Generating stratiform lidar variables for hydrometeor class pl
# Doing parallel lidar calculations for pl
# Stratiform moment for class pl progress: 0/24
# Generating stratiform lidar variables for hydrometeor class pi
# Doing parallel lidar calculations for pi
# Stratiform moment for class pi progress: 0/24
# Done! total processing time = 23.63s

# %%
# # Create simulated radar data
marcus_MWACR_ACCESS_AM2_model = emc2.simulator.main.make_simulated_data(ACCESS_AM2_instance, MWACR, N_columns = 1, do_classify = True, convert_zeros_to_nan = True, use_rad_logic = False, parallel = False)
# dir(marcus_MWACR_ACCESS_AM2_model)
# Out:
# ## Creating subcolumns...
# No convective processing for ACCESS_AM2
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns frac fields to 1 for startiform cl and ci based on q > 0. kg/kg
# Done! total processing time = 0.01s
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns frac fields to 1 for strat precip based on q > 0. kg/kg
# Done! total processing time = 0.01s
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for cl equal to grid-cell mean
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for ci equal to grid-cell mean
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for pl equal to grid-cell mean
# num_subcolumns == 1 (subcolumn generator turned off); setting subcolumns q (and N micro logic) fields for pi equal to grid-cell mean
# Generating radar moments...
# Generating stratiform radar variables using microphysics logic (slowest processing)
# Calculating moments for hydrometeor cl
# Processing column 0/24
# Calculating moments for hydrometeor ci
# Processing column 0/24
# Calculating moments for hydrometeor pl
# Processing column 0/24
# Calculating moments for hydrometeor pi
# Processing column 0/24
# Now calculating total spectral width (this may take some time)
# Stratiform moment for class cl progress: 0/85
# Stratiform moment for class progress: 0/24
# Stratiform moment for class progress: 0/24
# Stratiform moment for class progress: 0/24
# Done! total processing time = 6.01s

# %%
backscatter = marcus_MPL_ACCESS_AM2_model.ds['sub_col_beta_p_tot'].values
backscatter[np.isinf(backscatter)] = np.nan
print(np.nanmax(backscatter[np.nonzero(backscatter)]))
print(np.nanmin(backscatter[np.nonzero(backscatter)]))
print(backscatter[0,12])
# Out:
# 0.1069895881477876
# 4.2167615954244447e-10
# [1.16318532e-07 1.32489008e-07 1.61929928e-07 3.35913422e-03
#  7.96319662e-03 1.01299641e-02 6.29794812e-03 2.03046413e-03
#  7.64375566e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.14869508e-03 4.97572645e-03 5.79019385e-03 6.21862514e-03
#  6.40671228e-03 6.10114017e-03 5.59831830e-03 5.01108402e-03
#  4.39946231e-03 3.76885373e-03 3.17986293e-03 2.61955769e-03
#  2.13722058e-03 1.70592392e-03 1.28417690e-03 9.15759739e-04
#  6.59543241e-04 4.84981031e-04 3.57157149e-04 2.63309834e-04
#  1.95453564e-04 1.46154283e-04 1.11583072e-04 8.86036778e-05
#  7.24636906e-05 6.02578595e-05 4.83969460e-05 3.35564562e-05
#  3.10462106e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00]

# %%
depol = marcus_MPL_ACCESS_AM2_model.ds['sub_col_LDR_strat'].values
depol[np.isinf(backscatter)] = np.nan
print(np.nanmax(depol[np.nonzero(depol)]))
print(np.nanmin(depol[np.nonzero(depol)]))
print(depol[0,12])
# Out:
# 0.35000000000000003
# 0.2521239051678627
# [0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35  nan  nan  nan 0.35 0.35
#  0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35
#  0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35 0.35  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan]

# %%
reflectivity = marcus_MWACR_ACCESS_AM2_model.ds['sub_col_Ze_tot_strat'].values
reflectivity[np.isinf(reflectivity)] = np.nan
print(np.nanmax(reflectivity[np.nonzero(reflectivity)]))
print(np.nanmin(reflectivity[np.nonzero(reflectivity)]))
print(reflectivity[0,12])
# Out:
# -33.457212477712915
# -120.70602614147242
# [          nan           nan           nan  -59.72390427  -53.4986251
#   -54.28735189  -58.41552925  -65.74390277  -57.54428383           nan
#            nan           nan  -65.53086843  -63.16644669  -62.40393349
#   -62.00318878  -61.8769468   -62.23088522  -62.79971602  -63.50892707
#   -64.32258822  -65.2692837   -66.2858114   -67.42564902  -68.60684697
#   -69.90345966  -71.53267355  -73.50585516  -75.53500135  -77.60442462
#   -79.87324986  -82.41220338  -85.30563899  -88.68318845  -92.52669023
#   -96.57311572 -100.51157377 -103.94143409 -107.39771588 -112.120334
#  -108.67419849           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan
#            nan           nan           nan           nan           nan]

# %%
# Save the plot
# UM_reg_emc2_output_backscatter.savefig(f'/g/data/jk72/ck4840/projects/emc2/figs/um_reg/emc2_test/UM_reg_emc2_output_backscatter_{current_date_str}', dpi = 200)
# Open files and extract current date

# Create a meshgrid for time and height to be used for all plots produced from the current file
time_mesh, height_mesh = np.meshgrid(marcus_MPL_ACCESS_AM2_model.ds['time'], marcus_MPL_ACCESS_AM2_model.ds['z1_hybrid_height'])

# Backscatter
# Extract the desired variable
backscatter = marcus_MPL_ACCESS_AM2_model.ds['sub_col_beta_p_tot_strat'].isel(subcolumn=0).drop('subcolumn')
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, backscatter.T, cmap = 'viridis', shading = 'auto', norm = LogNorm())
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Backscatter (1/m*sr)')
plt.title('Backscatter vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
UM_reg_emc2_output_backscatter = plt.gcf()

# Depol
# Extract the desired variable
depol = marcus_MPL_ACCESS_AM2_model.ds['sub_col_LDR_strat'].isel(subcolumn=0).drop('subcolumn')
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, depol.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'LDR')
plt.title('Linear depolarization ratio vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
UM_reg_emc2_output_depol = plt.gcf()

# Reflectivity
# Extract the desired variable
reflectivity = marcus_MPL_ACCESS_AM2_model.ds['sub_col_Ze_tot_strat'].isel(subcolumn=0).drop('subcolumn')
# Create the plot with a grey background
plt.figure(figsize = (12, 6))
plt.gca().set_facecolor('lightgrey')
# Create and organise a pcolormesh plot
pcm = plt.pcolormesh(time_mesh, height_mesh, reflectivity.T, cmap = 'viridis', shading = 'auto')
plt.xlabel('Time')
plt.ylabel('Height (m)')
plt.colorbar(pcm, label = 'Reflectivity (dBZ)')
plt.title('Reflectivity vs. time and height')
plt.ylim(0, 4000)
plt.xticks(rotation = 45)
plt.tight_layout()
UM_reg_emc2_output_reflectivity = plt.gcf()
